# %% [markdown]
# Exercise 1

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('hacker_news.csv')
df
# Out:
#              id                                              title  \
# 0      12224879                          Interactive Dynamic Video
# 1      11964716  Florida DJs May Face Felony for April Fools' W...
# 2      11919867       Technology ventures: From Idea to Enterprise
# 3      10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4      10482257  Title II kills investment? Comcast and other I...
# ...         ...                                                ...
# 20094  12379592  How Purism Avoids Intels Active Management Tec...
# 20095  10339284          YC Application Translated and Broken Down
# 20096  10824382  Microkernels are slow and Elvis didn't do no d...
# 20097  10739875                      How Product Hunt really works
# 20098  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 0                http://www.interactivedynamicvideo.com/         386
# 1      http://www.thewire.com/entertainment/2013/04/f...           2
# 2      https://www.amazon.com/Technology-Ventures-Ent...           3
# 3      http://www.nytimes.com/2007/11/07/movies/07ste...           8
# 4      http://arstechnica.com/business/2015/10/comcas...          53
# ...                                                  ...         ...
# 20094  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20095  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20096  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20097  https://medium.com/@benjiwheeler/how-product-h...         695
# 20098              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 0                52       ne0phyte    8/4/2016 11:52
# 1                 1       vezycash   6/23/2016 22:20
# 2                 1        hswarna    6/17/2016 0:01
# 3                 2     walterbell    9/30/2015 4:12
# 4                22         Deinos   10/31/2015 9:48
# ...             ...            ...               ...
# 20094             6  AdmiralAsshat    8/29/2016 2:22
# 20095             1       zreitano   10/6/2015 14:57
# 20096           132    vezzy-fnord     1/2/2016 0:49
# 20097           222          brw12  12/15/2015 19:32
# 20098            58      pmoriarty    5/12/2016 1:43
#
# [20099 rows x 7 columns]

# %% [markdown]
# Exercise 2

# %%
first_five_rows = df.head()
first_five_rows
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  11964716  Florida DJs May Face Felony for April Fools' W...
# 2  11919867       Technology ventures: From Idea to Enterprise
# 3  10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4  10482257  Title II kills investment? Comcast and other I...
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://www.thewire.com/entertainment/2013/04/f...           2
# 2  https://www.amazon.com/Technology-Ventures-Ent...           3
# 3  http://www.nytimes.com/2007/11/07/movies/07ste...           8
# 4  http://arstechnica.com/business/2015/10/comcas...          53
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1             1    vezycash  6/23/2016 22:20
# 2             1     hswarna   6/17/2016 0:01
# 3             2  walterbell   9/30/2015 4:12
# 4            22      Deinos  10/31/2015 9:48

# %% [markdown]
# Exercise 3

# %%
last_five_rows = df.tail()
last_five_rows
# Out:
#              id                                              title  \
# 20094  12379592  How Purism Avoids Intels Active Management Tec...
# 20095  10339284          YC Application Translated and Broken Down
# 20096  10824382  Microkernels are slow and Elvis didn't do no d...
# 20097  10739875                      How Product Hunt really works
# 20098  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 20094  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20095  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20096  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20097  https://medium.com/@benjiwheeler/how-product-h...         695
# 20098              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 20094             6  AdmiralAsshat    8/29/2016 2:22
# 20095             1       zreitano   10/6/2015 14:57
# 20096           132    vezzy-fnord     1/2/2016 0:49
# 20097           222          brw12  12/15/2015 19:32
# 20098            58      pmoriarty    5/12/2016 1:43

# %% [markdown]
# Exeecise 4

# %%
title_col = df['title']
title_col
# Out:
# 0                                Interactive Dynamic Video
# 1        Florida DJs May Face Felony for April Fools' W...
# 2             Technology ventures: From Idea to Enterprise
# 3        Note by Note: The Making of Steinway L1037 (2007)
# 4        Title II kills investment? Comcast and other I...
#                                ...
# 20094    How Purism Avoids Intels Active Management Tec...
# 20095            YC Application Translated and Broken Down
# 20096    Microkernels are slow and Elvis didn't do no d...
# 20097                        How Product Hunt really works
# 20098    RoboBrowser: Your friendly neighborhood web sc...
# Name: title, Length: 20099, dtype: object

# %% [markdown]
# Exercise 5

# %%
# Filter the titles which contain python
for t in title_col:
    if 'python' in t:
        print(t)
print()

# Filter the titles which contain JavaScript
for t in title_col:
    if 'JavaScript' in t:
        print(t)
# Out:
# IronPython 3 (python for .net) development restarted
# Learn data science in python by taking online course
# Show HN: Dplython, dplyr data manipulation for python
# Kickstarter for funding Micropython port to ESP8266
# DQN for Beginners in 200 lines of python code to play Flappy Bird with Keras
# Show HN: Venv2docker  create a docker image from a python virtualenv
# EasyMake  one python file instead tons of Makefile locs
# let in python (2014)
# Ptpython  better than ipython or bpython?
# Show HN: Stack overflow command line client added support to python 2
# The origins of the class Meta idiom in python
# Crypto and SSL toolkit for python (M2Crypto)
#
# Show HN: Hire JavaScript - Top JavaScript Talent
# Ask HN: Are there any projects or compilers which convert JavaScript to Java?
# If you write JavaScript tools or libraries, bundle your code before publishing
# Rollup.js: A next-generation JavaScript module bundler
# V8 JavaScript Engine: V8 Release 5.4
# Proposed JavaScript Standard Style
# Show HN: Design by Contract for JavaScript
# Show HN: Monkberry  a JavaScript library for building web user interfaces
# Introduction to asynchronous JavaScript
# Ask HN: How do I learn JavaScript after using it for years
# Performance Comparison of JavaScript Frameworks
# A Chinese JavaScript framework that aims to challenge JQuery
# Industry Leaders to Advance Standardization of Netscape's JavaScript (1996)
# Will TypeScript replace JavaScript in development?
# Show HN: A Simple JavaScript Speech Recognizer
# ElixirScript  Elixir to JavaScript
# Show HN: Phoenix  a lightweight OS X window manager scriptable with JavaScript
# Is your JavaScript function actually pure?
# JavaScript Cancelable Promises Proposal
# Ask HN: Any Site that teaches JavaScript the way RailsCasts.com teaches Rails?
# List of books to master JavaScript Development
# Ask HN: JavaScript code explainer?
# JavaScript Promises: Plain and Simple
# Ask HN: How to approach writing a web crawler that can handle JavaScript?
# Wordpress Admin Fully JavaScript
# Capture and report JavaScript errors with window.onerror
# JavaScript Fatigue
# Compile OCaml to JavaScript, Run on Node
# Show HN: Expounder  A small JavaScript library for more engaging tutorials
# Learning how to write a 3D engine from scratch in C#, TypeScript or JavaScript (2013)
# Microsoft Preps Alternate JavaScript Engine for Node.js
# Timbre.js: JavaScript Library for Objective Sound Programming
# Why You Should Learn JavaScript in 2016
# Need Help to Recall CSS in JavaScript  Dec***
# Show HN: Bodybuilder  an elasticsearch query body builder for JavaScript
# How JavaScript closures work under the hood
# Gmail disabled access when JavaScript is turned off
# A Taste of JavaScript's New Parallel Primitives
# Ask HN: Where's the best place or best way to learn JavaScript syntax?
# Drool: automated memory leak detection in JavaScript
# Show HN: Lerna: A tool for managing large JavaScript projects
# Ask HN: Re-learn JavaScript today, where to start?
# A Large-Scale Study of the Use of Eval in JavaScript Applications (2011) [pdf]
# A Simple JavaScript change to reduce your build size
# Making Music in a Browser: Recreating Theremin with JavaScript and Web Audio API
# The Genuine (JavaScript) Sieve of Eratosthenes
# JavaScript isn't ever going away, is it?
# Show HN: JavaScript for Designers  follow along for free
# Oracle releases new JavaScript framework
# Microsoft Edge's JavaScript engine to go open-source
# Explaining the Example in The Secret Life of Objects of Eloquent JavaScript
# Battle of JavaScript: The 4 Frameworks Leading the Pack in 2016
# 21 JavaScript Answers on Quora Every Developer Must Read
# Klipse plugin for JavaScript  JSFiddle
# I Turned Off JavaScript for a Week
# Tcl.js: robust, high-performance Tcl in JavaScript
# Ask HN: How do you manage complexity in large JavaScript applications
# Functions in JavaScript: Assess your skills
# JSClassFinder: Detecting class-like structures in legacy JavaScript code
# JavaScript libraries should be written in TypeScript
# Window JavaScript alert messagebox tutorial for beginners
# A ?-calculus interpreter in less than 200 lines of JavaScript
# JavaScript eval: direct vs. indirect call
# Show HN: FractalViewer: A JavaScript fractal explorer
# Show HN: I just made my first JavaScript library
# BrightWork's JavaScript SDK  build your back end faster
# A boilerplate of JavaScript things that mostly shouldn't exist
# Runtime.js??JavaScript library OS
# PHP framework Laravel selects Vue.js as default JavaScript framework
# Ask HN: Elm-like JavaScript framework?
# JavaScript Performance Updates in Microsoft Edge and Chakra
# Show HN: MoonQuery.js Mongo like querying of arrays in JavaScript
# JavaScript and me
# Show HN: A JavaScript String replace API that challenges the status quo
# Go bridges to JavaScript and Python
# Stop Styling React Components with JavaScript
# CurveCP in JavaScript
# Executing non-alphanumeric JavaScript without parentheses
# How to learn JavaScript
# Ask HN: Should Learn/switch to JavaScript Programming (a Java Developer)
# Show HN: TinyRave  SoundCloud for JavaScript Music
# Avoiding a JavaScript Monoculture
# Ask HN: What would it take to free TypeScript from the JavaScript shackles?
# The State of JavaScript: Front-End Frameworks  A Few Preliminary Results
# React/JavaScript fatigue
# The GhostWriter, a JavaScript 2D Game with Canvas
# JavaScript has beguiled the current generation of software developers
# Developing small JavaScript components WITHOUT frameworks
# Y combinator real life application: recursive memoization in JavaScript
# Show HN: Chevrotain  Fault-Tolerant JavaScript Parsing DSL
# New JavaScript: ES7 and beyond
# The State of JavaScript on Android in 2015 Is Poor (Jeff Atwood)
# JavaScript's new Date() causing 90% of Alibaba's internal compatibility issues
# 7 out of 10 most influential people on GitHub writing in JavaScript
# Good JavaScript front end libraries?
# Fable: F# to JavaScript Transpiler
# Comcast injects JavaScript into webpages to show copyright notices to customers
# Js-joda  Immutable date and time library for JavaScript
# 2014s JavaScript versus todays  How things were before and how they are now
# Emulating a 6502 in JavaScript [video]
# A cool way to use natural language in JavaScript
# An awesome set of JavaScript snippets for VIM with support of ES2015 and Node.js
# Promisees  JavaScript Promises Visualization
# Cash: a cross-platform implementation of Unix shell commands in JavaScript
# HTTP Live Streaming in JavaScript
# 10 Most Recommended JavaScript Scene Articles of 2015
# The Top 3 JavaScript Mistakes Youre Making Right Now (and How to Fix Them)
# Show HN: Highcharts  JavaScript charts in one line
# [JavaScript] to promise or to callback? This is the problem
# ES6 is Over-Engineering JavaScript
# An interactive way of blogging about JavaScript
# Show HN: Timesweet  Time tracking in pure JavaScript
# What are the best JavaScript IDEs and editors?
# JavaScript and Immutability -?How fast is fast enough?
# Show HN: ScriptObservatory.org  How much malicious JavaScript goes unnoticed?
# Show HN: Pangaea  Text preprocessing with JavaScript
# Show HN: Klipse  code evaluator pluggable on a web page clojure/ruby/JavaScript
# Show HN: Flasher.js  Easily Install JavaScript on ESP8266 WiFi IoT Devices
# Ask HN: Recommendations for Expert Level JavaScript Classes
# Samson and JavaScript
# Furnish JavaScript - Let the classes on DOM elements generate the CSS for you
# Type conversions from JavaScript to C++ in V8
# Simple Programs to Learn JavaScript Design Patterns
# SQLite compiled into JavaScript via Emscripten
# Interaction without JavaScript: common UI elements with a CSS-only pattern
# How to Write an Open Source JavaScript Library: 23 Free Lessons on Egghead.io
# Show HN: First Release of Transcrypt Python3.5 to JavaScript Compiler
# Book on JavaScript Tools: Gulp, NPM, Yeoman, Bower
# A case in defense of ES6 generators in JavaScript
# Creating a JavaScript object without the new keyword
# JavaScript is immature compared to Java
# Using Vim as a JavaScript IDE
# Global namespaced to Common JS Modules in JavaScript with babel
# Show HN: Easily Add a CMS to Your JavaScript App
# Should We Limit Web Development to JavaScript?
# Top-level await in JavaScript is a footgun
# Show HN: Aspect-oriented mixins in JavaScript
# I Hate JavaScript
# Gordon  open source Flash runtime written in pure JavaScript
# JavaScript 101  Free 5+ hour course for Beginners
# Ask HN: Technologies to create a brand new JavaScript application?
# Feathers 2.0  a minimalist real-time JavaScript framework
# Pluggable.js: A tiny plugin architecture for your JavaScript project
# Made a small JavaScript library for smooth pretty drawing/handwriting on Canvas
# The Master JavaScript Course Has Been Released (197 Spots Remaining)
# Show HN: JavaScript coding challenges on top of GitHub and circleci
# Show HN: A simple, visual way of debugging JavaScript
# The master's thesis that led to the Karma Test Runner for JavaScript
# 10 very good reasons to stop using JavaScript
# Guidelines to choose a JavaScript library
# Show HN: Learn to code with JavaScript (French)
# Isomorphic JavaScript, lets make it easier
# We found a JavaScript UI library that performs great on Android mobile web
# Imgur.com exploit that allowed arbitrary JavaScript to be embedded
# How can JavaScript be stopped from spreading like a cancer?
# Famo.us pivots from JavaScript engine to micro-app CMS
# Immutable Data Structures and JavaScript
# Ask HN: What are examples of large websites without JavaScript?
# Show HN: Prolog compiler and interpreter in pure JavaScript
# Speed up JavaScript crypto
# Ask HN: Can anyone suggest great examples of continuation passing in JavaScript?
# Data Structures in JavaScript
# Show HN: LilBlog  Blog Software Written in Only HTML, CSS, and JavaScript
# The State of JavaScript on Android Is Poor
# Fotorama, a responsive JavaScript photo gallery
# Another Kind of JavaScript Fatigue
# Lonely programmer detective uncovers the Mozilla JavaScript coercion conspiracy
# Ask HN: Best Practices for CSS in a Modern JavaScript App
# Show HN: Parse recipe ingredients using JavaScript

# %%
df.describe()
# Out:
#                  id    num_points  num_comments
# count  2.009900e+04  20099.000000  20099.000000
# mean   1.131755e+07     50.296632     24.803025
# std    6.964531e+05    107.110322     56.108639
# min    1.017691e+07      1.000000      1.000000
# 25%    1.070172e+07      3.000000      1.000000
# 50%    1.128452e+07      9.000000      3.000000
# 75%    1.192613e+07     54.000000     21.000000
# max    1.257898e+07   2553.000000   1733.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20099 entries, 0 to 20098
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20099 non-null  int64
#  1   title         20099 non-null  object
#  2   url           17659 non-null  object
#  3   num_points    20099 non-null  int64
#  4   num_comments  20099 non-null  int64
#  5   author        20099 non-null  object
#  6   created_at    20099 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB
